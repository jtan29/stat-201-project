# %%
library(tidyverse)
library(tidymodels)
library(repr)
options(repr.matrix.max.rows = 6)
# library(cowplot)
library(digest)
library(infer)
library(repr)

# %%
url <-"https://raw.githubusercontent.com/jtan29/stat-201-project/main/student-mat.csv"
# read the dataset from temp file
student_data <- read_csv(url)
head(student_data)
# Out:
# Rows: 395 Columns: 33
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (17): school, sex, address, famsize, Pstatus, Mjob, Fjob, reason, guardi...
# dbl (16): age, Medu, Fedu, traveltime, studytime, failures, famrel, freetime...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   school sex age address famsize Pstatus Medu Fedu Mjob     Fjob     ⋯ famrel
# 1 GP     F   18  U       GT3     A       4    4    at_home  teacher  ⋯ 4
# 2 GP     F   17  U       GT3     T       1    1    at_home  other    ⋯ 5
# 3 GP     F   15  U       LE3     T       1    1    at_home  other    ⋯ 4
# 4 GP     F   15  U       GT3     T       4    2    health   services ⋯ 3
# 5 GP     F   16  U       GT3     T       3    3    other    other    ⋯ 4
# 6 GP     M   16  U       LE3     T       4    3    services other    ⋯ 5
#   freetime goout Dalc Walc health absences G1 G2 G3
# 1 3        4     1    1    3       6        5  6  6
# 2 3        3     1    1    3       4        5  5  6
# 3 3        2     2    3    3      10        7  8 10
# 4 2        2     1    1    5       2       15 14 15
# 5 3        2     1    2    5       4        6 10 10
# 6 4        2     1    2    5      10       15 15 15

# %%
student_data_clean <- 
    student_data %>%
    select(Walc, G3) %>%
    mutate(high_alc = Walc > 2)

head(student_data_clean)
# Out:
#   Walc G3 high_alc
# 1 1     6 FALSE
# 2 1     6 FALSE
# 3 3    10  TRUE
# 4 1    15 FALSE
# 5 2    10 FALSE
# 6 2    15 FALSE

# %%
student_group_size <-
    student_data_clean %>%
    group_by(high_alc) %>%
    summarize(count = n(),
             mean_grade = mean(G3),
             sd_grade = sd(G3))

student_group_size
high_alc_mean = student_group_size$mean_grade[[1]]
low_alc_mean = student_group_size$mean_grade[[2]]
high_alc_mean
low_alc_mean
# Out:
#   high_alc count mean_grade sd_grade
# 1 FALSE    236   10.50000   5.067628
# 2  TRUE    159   10.28931   3.757433
# [1] 10.5
# [1] 10.28931

# %%
options(repr.plot.width = 10, repr.plot.height = 6)
high_alc_sample_dist <-
    student_data_clean %>%
    filter(high_alc == TRUE) %>%
    ggplot(aes(x = G3)) +
    geom_histogram(binwidth = 1, fill = "lightblue",  color  = "blue") +
    labs(title = "Sample distribution of students with high alcohol consumption", x = "Final grade (out of 20)") +
    geom_vline(aes(xintercept = high_alc_mean), linetype = "dashed", color = "red", size = 1)



high_alc_sample_dist
    
low_alc_sample_dist <-
    student_data_clean %>%
    filter(high_alc == FALSE) %>%
    ggplot(aes(x = G3)) +
    geom_histogram(binwidth = 1, fill = "lightblue",  color  = "blue") +
    labs(title = "Sample distribution of students with low alcohol consumption", x = "Final grade (out of 20)") +
    geom_vline(aes(xintercept = low_alc_mean), linetype = "dashed", color = "red", size = 1)

low_alc_sample_dist
# Out:
# plot without title
# plot without title
