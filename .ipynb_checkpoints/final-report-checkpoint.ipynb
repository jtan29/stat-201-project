# %% [markdown]
# # Alcohol Consumption and Student Performance

# %% [markdown]
# ## Introduction

# %% [markdown]
# Drinking alcohol is a common aspect of daily life for many people, and students often turn to alcohol as a way to cope with stress. However, alcohol can have detrimental effects on people's bodies and nerves (1) and lead to aggressive behavior (2). Our group aimed to explore whether alcohol consumption influences the academic performance of different types of students. According to a study conducted by Ansari, Stock, and Mills in 2013, alcohol consumption is inversely associated with student achievement (3).
#
#
# For our group project, we utilized a dataset named "Student Alcohol Consumption", available at (https://www.kaggle.com/datasets/uciml/student-alcohol-consumption). This dataset includes information on students' gender, age, length of study, number of absences, weekend alcohol consumption (rated on a scale from 1 to 5, with 1 indicating very low and 5 indicating very high), and final grades (G3). The central question we aim to investigate is whether weekend drinking has a pronounced effect on students' academic grades. We plan to arrive at our final conclusion by calculating a location parameter: the difference in mean student grades between students with high alcohol consumption and students with low alcohol consumption. We will compare the mean scores of both groups to help draw conclusions regarding the impact of high alcohol consumption on student performance. Additionally, we are interested in investigating the standard deviation of test scores in both groups as a scale parameter.

# %% [markdown]
# ## Method and Results

# %% [markdown]
# ### Preliminary Analysis and Results

# %% [markdown]
# #### Preparing Data

# %% [markdown]
# We begin by preparing the required packages and reading our data set from the web.

# %%
library(tidyverse)
library(tidymodels)
library(repr)
options(repr.matrix.max.rows = 6)
library(digest)
library(infer)
library(repr)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.2     ✔ purrr   1.0.1
# ✔ tibble  3.2.1     ✔ dplyr   1.1.1
# ✔ tidyr   1.3.0     ✔ stringr 1.5.0
# ✔ readr   2.1.3     ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ── Attaching packages ────────────────────────────────────── tidymodels 1.0.0 ──
#
# ✔ broom        1.0.2     ✔ rsample      1.1.1
# ✔ dials        1.1.0     ✔ tune         1.0.1
# ✔ infer        1.0.4     ✔ workflows    1.1.2
# ✔ modeldata    1.0.1     ✔ workflowsets 1.0.0
# ✔ parsnip      1.0.3     ✔ yardstick    1.1.0
# ✔ recipes      1.0.4
#
# ── Conflicts ───────────────────────────────────────── tidymodels_conflicts() ──
# ✖ scales::discard() masks purrr::discard()
# ✖ dplyr::filter()   masks stats::filter()
# ✖ recipes::fixed()  masks stringr::fixed()
# ...

# %%
url <-"https://raw.githubusercontent.com/jtan29/stat-201-project/main/student-mat.csv"
student_data <- read_csv(url)
# Out:
# Rows: 395 Columns: 33
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (17): school, sex, address, famsize, Pstatus, Mjob, Fjob, reason, guardi...
# dbl (16): age, Medu, Fedu, traveltime, studytime, failures, famrel, freetime...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
print("Fig 1: Raw Data Set")
head(student_data)
# Out:
# [1] "Fig 1: Raw Data Set"
#   school sex age address famsize Pstatus Medu Fedu Mjob     Fjob     ⋯ famrel
# 1 GP     F   18  U       GT3     A       4    4    at_home  teacher  ⋯ 4
# 2 GP     F   17  U       GT3     T       1    1    at_home  other    ⋯ 5
# 3 GP     F   15  U       LE3     T       1    1    at_home  other    ⋯ 4
# 4 GP     F   15  U       GT3     T       4    2    health   services ⋯ 3
# 5 GP     F   16  U       GT3     T       3    3    other    other    ⋯ 4
# 6 GP     M   16  U       LE3     T       4    3    services other    ⋯ 5
#   freetime goout Dalc Walc health absences G1 G2 G3
# 1 3        4     1    1    3       6        5  6  6
# 2 3        3     1    1    3       4        5  5  6
# 3 3        2     2    3    3      10        7  8 10
# 4 2        2     1    1    5       2       15 14 15
# 5 3        2     1    2    5       4        6 10 10
# 6 4        2     1    2    5      10       15 15 15

# %% [markdown]
# In our investigation of the effects of high alcohol consumption on student performance, we divide students into two groups: students reporting high alcohol consumption and students reporting low alcohol consumption. The students' alcohol consumption was assessed on an index from 1 to 5, with 1 being very low and 5 being very high. We have designated students with an index of 3 or higher as belonging to the high-consumption group and students with an index of 2 or below as belonging to the low-consumption group. The following code produces another column in the data set corresponding to the group the student belongs to.

# %%
student_data_clean <- 
    student_data %>%
    select(Walc, G3) %>%
    mutate(high_alc = Walc > 2)
print("Fig 2: Processed Data Set")
head(student_data_clean)
# Out:
# [1] "Fig 2: Processed Data Set"
#   Walc G3 high_alc
# 1 1     6 FALSE
# 2 1     6 FALSE
# 3 3    10  TRUE
# 4 1    15 FALSE
# 5 2    10 FALSE
# 6 2    15 FALSE

# %% [markdown]
# #### Analysis of Raw Data

# %% [markdown]
# We first determine the mean final grade and the standard deviation of grades for the high and low consumption groups.

# %%
student_summary <-
    student_data_clean %>%
    group_by(high_alc) %>%
    summarize(count = n(),
             mean_grade = mean(G3),
             sd_grade = sd(G3))

low_alc_mean = student_summary$mean_grade[[1]]
high_alc_mean = student_summary$mean_grade[[2]]
total_count = student_summary$count[[1]] + student_summary$count[[2]]
print("Fig 3: Summary Table")
student_summary
# Out:
# [1] "Fig 3: Summary Table"
#   high_alc count mean_grade sd_grade
# 1 FALSE    236   10.50000   5.067628
# 2  TRUE    159   10.28931   3.757433

# %% [markdown]
# Then we plot the sample distribution of student grades for both groups.

# %%
options(repr.plot.width = 12, repr.plot.height = 8)

high_alc_sample_dist <-
    student_data_clean %>%
    filter(high_alc == TRUE) %>%
    ggplot(aes(x = G3)) +
    geom_histogram(binwidth = 1, fill = "lightblue",  color  = "blue") +
    labs(title = "Fig. 4: Sample distribution of students with high alcohol consumption", x = "Final grade (out of 20)") +
    geom_vline(aes(xintercept = high_alc_mean), linetype = "dashed", color = "red", linewidth = 1) +
    coord_cartesian(xlim = c(0, 20))


high_alc_sample_dist
    
low_alc_sample_dist <-
    student_data_clean %>%
    filter(high_alc == FALSE) %>%
    ggplot(aes(x = G3)) +
    geom_histogram(binwidth = 1, fill = "lightblue",  color  = "blue") +
    labs(title = "Fig. 5: Sample distribution of students with low alcohol consumption", x = "Final grade (out of 20)") +
    geom_vline(aes(xintercept = low_alc_mean), linetype = "dashed", color = "red", linewidth = 1) +
    coord_cartesian(xlim = c(0, 20))


low_alc_sample_dist
# Out:
# plot without title
# plot without title

# %% [markdown]
# We can also visually inspect a boxplot of the two groups.

# %%
boxplot <- student_data_clean %>%
              ggplot() +
              geom_boxplot(aes(x = high_alc, y = G3, fill = high_alc)) +
              labs(x = "High alcohol consumption reported", 
                   y = "Test score", 
                   fill = "High alcohol consumption reported", 
                   title = "Fig. 6: Comparison of test scores among students with high/low alcohol consumption")
boxplot
# Out:
# plot without title

# %% [markdown]
# Our anticipated result, based on existing literature on alcohol consumption, is that students with lower alcohol consumption receive higher grades on average (alternatively, this can be restated as students with higher reported alcohol consumption receiving lower grades on average). This is supported by the lower raw mean final grade in the high consumption group in our preliminary results, as can be observed in the boxplot above. However, the difference is small and could be attributed to random chance in the sampling process. To better determine if this difference is truly significant, we turn to hypothesis testing.

# %% [markdown]
# ### Hypothesis Testing

# %% [markdown]
# First, we must establish our null and alternative hypotheses. As stated in the preceding subsection, our initial assumption is that students with low alcohol consumption would achieve higher G3 grades compared to students with high alcohol consumption. This assumption forms the alternative hypothesis in this analysis, with the null hypothesis being that students consuming high volumes of alcohol achieve the same grades as students with low alcohol consumption. We can express the two hypotheses as follows:

# %% [markdown]
# $$H_0: \mu_1 - \mu_2 = 0$$
# $$H_a: \mu_1 - \mu_2 > 0$$

# %% [markdown]
# Where $\mu_1$ is the mean test score of all students with low alcohol consumption, and $\mu_2$ is the mean test score of all students with high alcohol consumption.

# %% [markdown]
# As part of hypothesis testing, we will calculate a p-value to determine whether to reject our null hypothesis. We set our significance level at $\alpha = 0.05$. However, just reporting the p-value does not capture all the relevant information about the two groups and the relationship between alcohol and student performance. We will also calculate a 95% confidence interval to provide an estimated interval which is likely to capture our unknown population parameter (the difference in mean student grades). Additionally, we intend to find the p-value and confidence interval using both non-traditional computer-based models and traditional theoretical models such as the t-distribution.

# %% [markdown]
# #### Simulation-Based Hypothesis Tests

# %% [markdown]
# We will begin our analysis with a simulation-based hypothesis test using the `infer` package in R. As a first step, we create the null model for our data.

# %%
set.seed(39)
null_sim <- student_data_clean  %>%
  specify(G3 ~ high_alc) %>%
  hypothesize(null = "independence") %>%
  generate(reps = 2000, type = "permute") %>%
  calculate(
    stat = "diff in means",
    order = c("FALSE", "TRUE")
  )
null_sim %>% visualize() +
    ggtitle("Fig 7: Simulation Based Null Distribution of Difference of Mean Student Grades")
# Out:
# plot without title

# %% [markdown]
# Next, we will calculate the difference between the mean student score in each sample, which is our point statistic:

# %%
obs_diff <- student_data_clean %>%
  specify(G3 ~ high_alc) %>%
  calculate(
    stat = "diff in means",
    order = c(FALSE, TRUE)
  )
print("Fig 8: Difference in sample means between high- and low-alcohol groups")
obs_diff
# Out:
# [1] "Fig 8: Difference in sample means between high- and low-alcohol groups"
#   stat
# 1 0.2106918

# %% [markdown]
# Below, we present the simulation-based null-model with the observed point statistic shaded in red.

# %%
null_sim %>%
  visualize() +
  shade_p_value(obs_stat = obs_diff, direction = "greater") +
  ggtitle("Fig 9: Simulation Based Null Distribution with Shaded Point Statistic")
# Out:
# plot without title

# %% [markdown]
# Which leads us to the simulation-derived p-value of:

# %%
print("Fig 10: Simulation-based P-Value")
pvalue <- null_sim %>%
  get_pvalue(obs_stat = obs_diff, direction = "greater")
pvalue
# Out:
# [1] "Fig 10: Simulation-based P-Value"
#   p_value
# 1 0.325

# %% [markdown]
# Our simulation-based hypothesis test finds a p-value of $0.325$.

# %% [markdown]
# We can then find 95% confidence interval for the difference of means, again with the `infer` package.

# %%
boot_ci <- student_data_clean %>%
  specify(G3 ~ high_alc) %>%
  generate(reps = 2000, type = "bootstrap") %>%
  calculate(
    stat = "diff in means",
    order = c(FALSE, TRUE)
)

# %%
conf_in <-   boot_ci %>%
    get_ci(level = 0.95)

print("Fig 11: Simulation-based Confidence Interval")
conf_in

boot_ci %>% visualize() +
    shade_ci(endpoints = conf_in) +
    ggtitle("Fig 12: Simulation-based Bootstrap Distribution with shaded confidence interval")
# Out:
# [1] "Fig 11: Simulation-based Confidence Interval"
#   lower_ci   upper_ci
# 1 -0.6710326 1.052799
# plot without title

# %% [markdown]
# Our 95% confidence interval provides us with a range of values where we would expect the true population parameter to land. Our bootstrap-based confidence interval places these bounds as a difference in mean score of $-0.701$ (students with low alcohol consumption score $0.701$ points below students with high alcohol consumption) and $1.093$ (students with low alcohol consumption score $1.093$ higher than students with high alcohol consumption). It is important here to note that the value of $0$ (students in either group performed the same) is included in this interval.

# %% [markdown]
# #### Theory-Based Hypothesis Testing

# %% [markdown]
# After obtaining a value from our simulation-based hypothesis testing, we are interested in determining any potential differences between our simulation-based test and a theory-based test. From our preliminary analysis, our data does not fully follow a normal distribution. However, the sample size is large enough for the Central Limit Theorem to apply, and we determine that it is suitable to use traditional theoretical hypothesis testing methods on the data. In particular, the most suitable test is a t-test for a difference in means of two independent groups, as the population's standard deviation is not known.

# %% [markdown]
# $$t =\frac{ (\bar{x}_1 - \bar{x}_2)}{ \sqrt{\frac{s_1^2}{n_1} + \frac{s_2^2}{n_2}}} \sim t (df = n_1 + n_2 - 2)$$

# %% [markdown]
# Our preliminary summary information provides us with all the information we need to calculate the p-value using a t-distribution with $n_1 + n_2 - 2 = 236 + 159 - 2 = 393$ degrees of freedom. It is provided again below for convenience.

# %%
print("Fig 3: Summary Table")
student_summary
# Out:
# [1] "Fig 3: Summary Table"
#   high_alc count mean_grade sd_grade
# 1 FALSE    236   10.50000   5.067628
# 2  TRUE    159   10.28931   3.757433

# %%
high_alc_mean <- student_summary$mean_grade[[1]]
low_alc_mean <- student_summary$mean_grade[[2]]
high_alc_sd <- student_summary$sd_grade[[1]]
low_alc_sd <- student_summary$sd_grade[[2]]
high_alc_n <- student_summary$count[[1]]
low_alc_n <- student_summary$count[[2]]

test_statistic <- abs(high_alc_mean - low_alc_mean) / sqrt(high_alc_sd ** 2 / high_alc_n + low_alc_sd ** 2 / low_alc_n)
p_value <- pt(test_statistic, df = high_alc_n + low_alc_n - 2, lower.tail = FALSE)
print("Fig. 13: Theoretical P-Value from two-sample t-test")
p_value
# Out:
# [1] "Fig. 13: Theoretical P-Value from two-sample t-test"
# [1] 0.3178959

# %% [markdown]
# Our theory-based hypothesis test finds a p-value of $0.318$.

# %% [markdown]
# We can then complete this analysis by providing a theory-based confidence interval for the difference in means.

# %%
upper_ci <- abs(high_alc_mean - low_alc_mean) + qt(0.975, df = high_alc_n + low_alc_n - 2) * sqrt(high_alc_sd ** 2 / high_alc_n + low_alc_sd ** 2 / low_alc_n)
lower_ci <- abs(high_alc_mean - low_alc_mean) - qt(0.975, df = high_alc_n + low_alc_n - 2) * sqrt(high_alc_sd ** 2 / high_alc_n + low_alc_sd ** 2 / low_alc_n)
ci <- bind_cols(as_tibble(c("upper_ci", "lower_ci")), as_tibble(c(upper_ci, lower_ci))) %>% rename("ci" = "value...1", "value" = "value...2")
print("Fig. 14: Theoretical 95% Confidence Interval")
ci
# Out:
# New names:
# • `value` -> `value...1`
# • `value` -> `value...2`
# [1] "Fig. 14: Theoretical 95% Confidence Interval"
#   ci       value
# 1 upper_ci  1.0846563
# 2 lower_ci -0.6632726

# %% [markdown]
# We find a theory-based confidence interval spanning from $\approx -0.663$ to $\approx 1.085$. This is consistent with our bootstrap distribution, and also includes zero within the interval. We can conclude that for our hypothesis test, the computer-based models produced similar results to the traditional theoretical models. This is not unexpected, as we previously assessed whether our data fulfilled the requirements for theoretical models such as the t-distribution to be effective. The similarity to the computer-based results, which have less stringent requirements on the data set, supports our assessment that traditional theoretical techniques were suitable in this case.

# %% [markdown]
# ### Confidence Interval for the Standard Deviation

# %% [markdown]
# We may also be interested in observing the standard deviation among test scores of students in both groups. Below, we present the bootstrap confidence intervals for the standard deviations of our high and low alcohol groups.

# %%
boot_low_sd <- student_data_clean %>%
  filter(high_alc == FALSE) %>%
  specify(response = G3) %>%
  generate(reps = 2000, type = "bootstrap") %>%
  calculate(
    stat = "sd"
)

# %%
conf_in_low <-   boot_low_sd %>%
    get_ci(level = 0.95)

print("Fig. 15: Confidence Interval of Standard Deviation of low-alcohol group")
conf_in_low

boot_low_sd %>% visualize() +
    shade_ci(endpoints = conf_in_low) +
    ggtitle("Fig. 16: Standard deviation of test scores (low alcohol) Bootstrap Distribution")
# Out:
# [1] "Fig. 15: Confidence Interval of Standard Deviation of low-alcohol group"
#   lower_ci upper_ci
# 1 4.589313 5.499968
# plot without title

# %%
boot_high_sd <- student_data_clean %>%
  filter(high_alc == TRUE) %>%
  specify(response = G3) %>%
  generate(reps = 2000, type = "bootstrap") %>%
  calculate(
    stat = "sd"
)

# %%
conf_in_high <-   boot_high_sd %>%
    get_ci(level = 0.95)

print("Fig. 17: Confidence Interval of Standard Deviation of high-alcohol group")
conf_in_high

boot_high_sd %>% visualize() +
    shade_ci(endpoints = conf_in_high) +
    ggtitle("Fig. 18: Standard deviation of test scores (high alcohol) Bootstrap Distribution")
# Out:
# [1] "Fig. 17: Confidence Interval of Standard Deviation of high-alcohol group"
#   lower_ci upper_ci
# 1 3.238745 4.24733
# plot without title

# %% [markdown]
# This would suggest that is much greater variability in the test scores of students that did not consume high volumes of alcohol.

# %% [markdown]
# # Discussion

# %% [markdown]
# Our hypothesis tests, both computer-based and theoretical, found similar p-values of $0.325$ and $0.318$ respectively. Both these values are much greater than our $\alpha = 0.05$. As a result, we **fail to reject the null hypothesis** and find that there is not sufficient evidence to support our alternative hypothesis that students who consume lower volumes of alcohol will have higher test scores. This is a somewhat unexpected finding, as our initial expectations were for students who consumed less alcohol would achieve high test scores compared to students that consumed more alcohol. We believe that some of this may be attributed to the large number of students reporting a final grade of zero. This is noticeable in the sample distribution of both groups, with 30 of the 236 students in the low alcohol group reporting a score of zero. This may indicate a problem with the data collection, particularly with the handling of students that did not report a test score or did not follow through with the entire data collection process.
#
# Also of concern is how the alcohol levels are determined, since there is no direct numerical measurement of the actual alcohol consumed. If the index is self-assessed, it is possible that students that consume the same amount of alcohol will self-assess into different groups based on their perception of what constitutes high and low alcohol consumption. Additionally, if the alcohol levels are self-reported, students may not feel comfortable reporting their actual consumption habits.

# %% [markdown]
# Future investigations could focus on revising how the data is collected to prevent students presenting invalid scores from being included in the data set as well as allow for more objective measuring of the volume of alcohol consumed. Future questions this could lead to may include investigations seek to more finely quantify the volume of alcohol consumed, in order to investigate the volume needed for changes in grades to be observed.

# %% [markdown]
# # References

# %% [markdown]
# (1). Michael J. Eckardt, Sandra E. File, et.Effects of Moderate Alcohol Consumption on the Central Nervous System. 30 May 2006. https://doi.org/10.1111/j.1530-0277.1998.tb03695.x
#
# (2). Bushman, B. J., & Cooper, H. M. . Effects of alcohol on human aggression: An intergrative research review. Psychological Bulletin, 107(3), 341–354.(1990). https://doi.org/10.1037/0033-2909.107.3.341
#
# (3). El Ansari W, Stock C, Mills C. Is alcohol consumption associated with poor academic achievement in university students? Int J Prev Med. Oct 2013;4(10):1175-88. PMID: 24319558; PMCID: PMC3843305. https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3843305/
